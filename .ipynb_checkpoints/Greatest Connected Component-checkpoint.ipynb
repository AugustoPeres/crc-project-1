# %%
from itertools import count
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
from importmarvel import create_marvel_graph
from colorspacious import cspace_converter
from collections import OrderedDict
import collections
import pandas as pd

# %%
G=nx.read_graphml('connectcomp.graphml')

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 6449
# Number of edges: 168211
# Average degree:  52.1665

# %%
deglist=list(range(0,len(degfreq)))

# %% [markdown]
# ## First visualization of the network

# %%
# %matplotlib notebook

val_map = {}

for node in G:
    val_map[str(node)] = G.degree(node)
val_map

values = [val_map.get(node, 0.25) for node in G.nodes()]

options = {
    'node_size': 5,
    'line_color': 'grey',
    'linewidths': 0,
    'width': 0.01,
    'alpha': 0.3,
}

nx.draw(G, cmap=plt.get_cmap('jet'),  node_color = values, **options)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

val_map = {}

for node in G:
    val_map[str(node)] = G.degree(node)
val_map

values = [val_map.get(node, 0.25) for node in G.nodes()]

options = {
    'node_size': 5,
    'line_color': 'grey',
    'linewidths': 0,
    'width': 0.01,
    'alpha': 0.3,
}

nx.draw_spring(G, cmap=plt.get_cmap('jet'),  node_color = values, **options)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

val_map = {}

for node in G:
    val_map[str(node)] = G.degree(node)
val_map

values = [val_map.get(node, 0.25) for node in G.nodes()]

options = {
    'node_size': 5,
    'line_color': 'grey',
    'linewidths': 0,
    'width': 0.01,
    'alpha': 0.3,
}

nx.draw_kamada_kawai(G, cmap=plt.get_cmap('jet'),  node_color = values, **options)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="927">

# %%
#DEGREE DISTRIBUTION
plt.plot(deglist,degfreq)
plt.show()

# %%
#LOGLOG DEGREE DISTRIBUTION
plt.loglog(deglist,degfreq)
plt.show()

# %%
#LOGLOG CUMULATIVE DEGREE DISTRIBUTION
cumdegfreq=[0]*1934
sum=0;

for i in range(0,1934):
    sum+=degfreq[i]
    cumdegfreq[i]=sum
cumdegfreq.reverse()
    
plt.loglog(deglist,cumdegfreq)
plt.show()

# %%
#SAME AS BEFORE BUT CHANGING THE ORDER (OF THE COMULATIVE VALUES)
cumdegfreq.reverse()
plt.loglog(deglist,cumdegfreq)
plt.show()

# %%
BG=nx.read_graphml('bipartitegraph.graphml')
BGlabels=nx.get_node_attributes(BG,'label')

# %%
#DEGREE CENTRALITY
#GET THE HEROS WITH MOST CONNECTIONS (DEG CENTRALITY>= dg)

dg=0.17

degcent=nx.degree_centrality(G)

largestnodes=[]

for i in range(1,6486):
    if str(i) in degcent.keys():
        z= degcent[str(i)]
        if z>=dg:
            largestnodes.append([BGlabels[str(i)],z])
#sorting by centrality
largestnodes.sort(key = lambda x: x[1])
largestnodes
# Out:
# [['CYCLOPS/SCOTT SUMMER', 0.17121588089330025],
#  ['HAWK', 0.18238213399503722],
#  ['INVISIBLE WOMAN/SUE ', 0.19292803970223324],
#  ['VISION ', 0.19587468982630274],
#  ['BEAST/HENRY &HANK& P', 0.19851116625310172],
#  ['THOR/DR. DONALD BLAK', 0.19990694789081886],
#  ['SCARLET WITCH/WANDA ', 0.20859181141439206],
#  ['HUMAN TORCH/JOHNNY S', 0.2126240694789082],
#  ['MR. FANTASTIC/REED R', 0.2149503722084367],
#  ['WOLVERINE/LOGAN ', 0.2161910669975186],
#  ['THING/BENJAMIN J. GR', 0.22115384615384615],
#  ['IRON MAN/TONY STARK ', 0.2369727047146402],
#  ['SPIDER-MAN/PETER PAR', 0.2700062034739454],
#  ['CAPTAIN AMERICA', 0.29978287841191065]]

# %%
len(largestnodes)
# Out:
# 14

# %%
#EIGENVECTOR CENTRALITY
#GET THE HEROS WITH MORE IMPORTANT CONNECTIONS (DEIGEN CENTRALITY>= Eg)

eg=0.09

eigencent=nx.eigenvector_centrality(G)

eigentopnodes=[]

for i in range(1,6486):
    if str(i) in eigencent.keys():
        z= eigencent[str(i)]
        if z>=eg:
            eigentopnodes.append([BGlabels[str(i)],z])
eigentopnodes
# Out:
# [['BEAST/HENRY &HANK& P', 0.09564944501935423],
#  ['CAPTAIN AMERICA', 0.11698385668430927],
#  ['CYCLOPS/SCOTT SUMMER', 0.09118696524018356],
#  ['HUMAN TORCH/JOHNNY S', 0.09828114297147897],
#  ['INVISIBLE WOMAN/SUE ', 0.09484014203135523],
#  ['IRON MAN/TONY STARK ', 0.10224305023526165],
#  ['MR. FANTASTIC/REED R', 0.09954368007972826],
#  ['SCARLET WITCH/WANDA ', 0.10135798279453614],
#  ['SHE-HULK/JENNIFER WA', 0.09168329227149498],
#  ['SPIDER-MAN/PETER PAR', 0.09992670831944055],
#  ['THING/BENJAMIN J. GR', 0.10053877650740471],
#  ['THOR/DR. DONALD BLAK', 0.09428342934991332],
#  ['VISION ', 0.09920072980649595],
#  ['WASP/JANET VAN DYNE ', 0.09092178508003176],
#  ['WOLVERINE/LOGAN ', 0.09911596172237201]]

# %%
len(eigentopnodes)
# Out:
# 15

# %%
#CLOSENESS CENTRALITY
#GET THE HEROS WITH MORE IMPORTANT CONNECTIONS (DEIGEN CENTRALITY>= Eg)

cc=0.55

#closecent=nx.closeness_centrality(G)

closetopnodes=[]

for i in range(1,6486):
    if str(i) in closecent.keys():
        z= closecent[str(i)]
        if z>=cc:
            if i==4656:
                closetopnodes.append(['unknown character',z])
            else:
                closetopnodes.append([BGlabels[str(i)],z])
            
closetopnodes
# Out:
# [['BEAST/HENRY &HANK& P', 0.5509698367939845],
#  ['CAPTAIN AMERICA', 0.5861285337696573],
#  ['HUMAN TORCH/JOHNNY S', 0.5564857167515319],
#  ['INVISIBLE WOMAN/SUE ', 0.5501706484641639],
#  ['IRON MAN/TONY STARK ', 0.5628491620111732],
#  ['MR. FANTASTIC/REED R', 0.5575443147427583],
#  ['SCARLET WITCH/WANDA ', 0.5544282029234737],
#  ['SPIDER-MAN/PETER PAR', 0.5754060324825986],
#  ['THING/BENJAMIN J. GR', 0.5593823197709725],
#  ['THOR/DR. DONALD BLAK', 0.552054794520548],
#  ['VISION ', 0.5501706484641639],
#  ['WOLVERINE/LOGAN ', 0.5572070515036295]]

# %%
#testes: confirma-se que o vértice 4656 é o único que não tem nome
for i in range(1,6486):
    if i==4656:
        1+1
    else:
        BGlabels[str(i)]

# %% [markdown]
# ## Average clustering

# %%
nx.average_clustering(G)
# Out:
# 0.775857832582658

# %% [markdown]
# ## Average shortest paths

# %%
nx.average_shortest_path_length(G)
# Out:
# 2.6373681821907105
